# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
def test_image(model, image_path):

  # Load the image
  img = cv2.imread(image_path)
  plt.imshow(img)
  img = cv2.resize(img, (224, 224))
  #plt.imshow(img)
  img = img.astype(np.float32) / 255.
  image = np.stack(img, axis=0)
  print(image.shape)
  image = np.array([image])
  # Predict the class of the image
  prediction = model.predict(image)

  # Get the predicted class label
  predicted_class = np.argmax(prediction)

  # Return the predicted class label
  return predicted_class

# %%
model1 = tf.keras.models.load_model('C:/Users/nani1/OneDrive/Desktop/Densenet 201/40 epochs/densenet201_40.h5')

# %%
image_path = 'C:/Users/nani1/OneDrive/Desktop/oral cancer dataset/Oral Cancer/oral_scc/oral_scc_0120.jpg'

# Test the image
predicted_class = test_image(model1, image_path)

if predicted_class==1:
  label='Cancer'
else:
  label='Not Cancer'
print(f"Predicted class label: {label}")
# Out:
# (224, 224, 3)
# 1/1 [==============================] - 18s 18s/step
# Predicted class label: Cancer

# %%
image_path = 'C:/Users/nani1/OneDrive/Desktop/oral cancer dataset/Oral Cancer/oral_scc/oral_scc_0120.jpg'

# Test the image
predicted_class = test_image(model1, image_path)

if predicted_class==1:
  label='Cancer'
else:
  label='Not Cancer'
print(f"Predicted class label: {label}")
# Out:
# (224, 224, 3)
# 1/1 [==============================] - 1s 752ms/step
# Predicted class label: Cancer

# %%
image_path = 'C:/Users/nani1/OneDrive/Desktop/oral cancer dataset/Oral Cancer/oral_normal/oral_normal_0267.jpg'

# Test the image
predicted_class = test_image(model1, image_path)

if predicted_class==1:
  label='Cancer'
else:
  label='Not Cancer'
print(f"Predicted class label: {label}")
# Out:
# (224, 224, 3)
# 1/1 [==============================] - 1s 713ms/step
# Predicted class label: Not Cancer

# %%
image_path = 'C:/Users/nani1/OneDrive/Desktop/oral cancer dataset/Oral Cancer/oral_normal/oral_normal_0563.jpg'

# Test the image
predicted_class = test_image(model1, image_path)

if predicted_class==1:
  label='Cancer'
else:
  label='Not Cancer'
print(f"Predicted class label: {label}")
# Out:
# (224, 224, 3)
# 1/1 [==============================] - 1s 722ms/step
# Predicted class label: Not Cancer
